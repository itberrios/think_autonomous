# %% [markdown]
# #Welcome to the Drivable Area Detection Project!
#
# * Course: https://jeremycohen.podia.com/image-segmentation
#
# In this project, you will train a Deep Learning algorithm to detect Drivable Area.
# You will work on 3 aspects of the segmentation algorithm:
# 1. [Data Collection](#Data)
# 2. [Model Definition & Training](#Model)
# 3. [Model Run in a real-time video feed](#Video)

# %% [markdown]
# **GPU**<p>
# This shouldn't be needed. You can run it just in case.<p>
# Know that Colab uses Tensorflow 2.0 that included Keras.<p>
# Be sure to use GPU environment by selecting **Runtime** > **GPU** above.

# %%
## USE GPU
import tensorflow as tf
from tensorflow.python.client import device_lib
# LIST GPUS AVAILABLE
print(device_lib.list_local_devices())
import tensorflow.python.keras
config = tf.compat.v1.ConfigProto( device_count = {'GPU': 1 , 'CPU': 56} ) 
sess = tf.compat.v1.Session(config=config) 
tensorflow.python.keras.backend.set_session(sess)

# %% [markdown]
# # <a name="Data"></a>1. Data Collect, Visualization, Augmentation
#
# This project will use the [BDD 100K Dataset](https://bdd-data.berkeley.edu/).<p>
#
# It was downloaded from [this website](https://bdd-data.berkeley.edu/login.html) and then dumped into a pickle file.<p>-<p>
#
# If you want to repeat the process, go to the [download page](https://bdd-data.berkeley.edu/portal.html#download) (once logged in) and click on the buttons **Images** and **Driverable Maps** under the BDD100K section.
# It will download the necessary dataset. Then pick a subset of it.
# Use Google Chrome and in case it doesn't work, hit the button again until it does.<p>-<p>
#
#
# **Use the provided pickle file**<p>
# I have downloaded the images and labels. It took a few hours.<p>
# I selected **3,000 images** and **their associated labels** and put them into **2 separate pickle files**. <p>Each image has been resized to **160x80** for memory reasons. <p>
# **Original 1280x720** images are also available in the course.
#
# <p>-<p>In this part you will load the dataset and adapt it so it fits your neural network.

# %% [markdown]
# ## Load the Dataset, Visualize Images & Labels

# %% [markdown]
# **Library Import**

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import cv2
import pickle

# %% [markdown]
# **Load the Pickle files**

# %%
with open("../segmentation_dataset/images_3000_original.p", 'rb') as f:
    images = pickle.load(f)

with open("../segmentation_dataset/processed_labels_3000_original_1_REDUCED.p","rb") as f:
    labels_1 = pickle.load(f)

with open("../segmentation_dataset/processed_labels_3000_original_2_REDUCED.p","rb") as f:
    labels_2 = pickle.load(f)

## NOTE : File has been pickle.dump() with Python 2 so this syntax is necessary to open it with Python 3. Otherwise the following would be enough :
#images = pickle.load(open("images.p","rb", encoding='latin1)) # Pickle Dump using Python 2
#images = pickle.load(open("images.p","rb")) ## Pickle Dump using Python 3

# %% [markdown]
# **Display a random image and its label**<p>
# Print dataset information

# %%
import random
index = random.randint(0,len(labels))
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(20,10))
ax1.imshow(images[index].squeeze())
ax1.set_title('Image', fontsize=30)
label = np.unpackbits(labels[index], count=2764800).reshape((720, 1280, 3)).astype(np.float32)
ax2.imshow(label)
ax2.set_title('Label', fontsize=30)
# Out:
# Text(0.5, 1.0, 'Label')

# %%
print("There are "+ str(len(images))+ " images and "+ str(len(labels)) +" labels in the dataset")
print("Shape of an image")
print(images[0].shape)
print("Shape of a Label")
print(label.shape)
print("Images range from "+str(np.amin(images[0]))+" to "+str(np.amax(images[0])))
print("Labels range from "+str(np.amin(labels[0]))+" to "+str(np.amax(labels[0])))
# Out:
# There are 3000 images and 1500 labels in the dataset
# Shape of an image
# (720, 1280, 3)
# Shape of a Label
# (720, 1280, 3)
# Images range from 0 to 255
# Labels range from 18 to 164

# %% [markdown]
# #### Save images and labels as actual images to be used with a DataLoader

# %%
label = 255*(np.unpackbits(labels[index], count=2764800).reshape((720, 1280, 3))).astype(np.uint8)
np.unique(label)
# Out:
# array([  0, 255], dtype=uint8)

# %%
labels = labels_1 + labels_2

print(len(images))
print(len(labels))

# get train test split without shuffling
train_images = images[:2000]
train_labels = images[:2000]

train_images = images[2000:2500]
train_labels = images[2000:2500]

train_images = images[2500:]
train_labels = images[2500:]
# Out:
# 3000
# 3000

# %%
import cv2 

IMAGE_SAVE_PATH = '..\segmentation_dataset\images'
LABEL_SAVE_PATH = '..\segmentation_dataset\labels'

for i, (image, label) in enumerate(zip(images, labels)):
    name = str(i).rjust(9, '0') + '.png'

    # cv2.imwrite(os.path.join(IMAGE_SAVE_PATH, name), image)
    
    # convert label to 8bit array
    label = 255*(np.unpackbits(label, count=2764800).reshape((720, 1280, 3))).astype(np.uint8)
    cv2.imwrite(os.path.join(LABEL_SAVE_PATH, name), label)

# %%
from glob import glob

data_path = "../segmentation_dataset"
glob(os.path.join(data_path, 'images/*.png'))
# Out:
# ['../segmentation_dataset\\images\\000000000.png',
#  '../segmentation_dataset\\images\\000000001.png',
#  '../segmentation_dataset\\images\\000000002.png',
#  '../segmentation_dataset\\images\\000000003.png',
#  '../segmentation_dataset\\images\\000000004.png',
#  '../segmentation_dataset\\images\\000000005.png',
#  '../segmentation_dataset\\images\\000000006.png',
#  '../segmentation_dataset\\images\\000000007.png',
#  '../segmentation_dataset\\images\\000000008.png',
#  '../segmentation_dataset\\images\\000000009.png',
#  '../segmentation_dataset\\images\\000000010.png',
#  '../segmentation_dataset\\images\\000000011.png',
#  '../segmentation_dataset\\images\\000000012.png',
#  '../segmentation_dataset\\images\\000000013.png',
#  '../segmentation_dataset\\images\\000000014.png',
#  '../segmentation_dataset\\images\\000000015.png',
#  '../segmentation_dataset\\images\\000000016.png',
#  '../segmentation_dataset\\images\\000000017.png',
#  '../segmentation_dataset\\images\\000000018.png',
#  '../segmentation_dataset\\images\\000000019.png',
#  '../segmentation_dataset\\images\\000000020.png',
#  '../segmentation_dataset\\images\\000000021.png',
#  '../segmentation_dataset\\images\\000000022.png',
#  '../segmentation_dataset\\images\\000000023.png',
#  '../segmentation_dataset\\images\\000000024.png',
#  '../segmentation_dataset\\images\\000000025.png',
#  '../segmentation_dataset\\images\\000000026.png',
#  '../segmentation_dataset\\images\\000000027.png',
#  '../segmentation_dataset\\images\\000000028.png',
#  '../segmentation_dataset\\images\\000000029.png',
#  '../segmentation_dataset\\images\\000000030.png',
#  '../segmentation_dataset\\images\\000000031.png',
#  '../segmentation_dataset\\images\\000000032.png',
#  '../segmentation_dataset\\images\\000000033.png',
#  '../segmentation_dataset\\images\\000000034.png',
#  '../segmentation_dataset\\images\\000000035.png',
#  '../segmentation_dataset\\images\\000000036.png',
#  '../segmentation_dataset\\images\\000000037.png',
#  '../segmentation_dataset\\images\\000000038.png',
#  '../segmentation_dataset\\images\\000000039.png',
#  '../segmentation_dataset\\images\\000000040.png',
#  '../segmentation_dataset\\images\\000000041.png',
#  '../segmentation_dataset\\images\\000000042.png',
#  '../segmentation_dataset\\images\\000000043.png',
#  '../segmentation_dataset\\images\\000000044.png',
#  '../segmentation_dataset\\images\\000000045.png',
#  '../segmentation_dataset\\images\\000000046.png',
#  '../segmentation_dataset\\images\\000000047.png',
#  '../segmentation_dataset\\images\\000000048.png',
#  '../segmentation_dataset\\images\\000000049.png',
#  '../segmentation_dataset\\images\\000000050.png',
#  '../segmentation_dataset\\images\\000000051.png',
#  '../segmentation_dataset\\images\\000000052.png',
#  '../segmentation_dataset\\images\\000000053.png',
#  '../segmentation_dataset\\images\\000000054.png',
#  '../segmentation_dataset\\images\\000000055.png',
#  '../segmentation_dataset\\images\\000000056.png',
#  '../segmentation_dataset\\images\\000000057.png',
#  '../segmentation_dataset\\images\\000000058.png',
#  '../segmentation_dataset\\images\\000000059.png',
#  '../segmentation_dataset\\images\\000000060.png',
#  '../segmentation_dataset\\images\\000000061.png',
#  '../segmentation_dataset\\images\\000000062.png',
#  '../segmentation_dataset\\images\\000000063.png',
#  '../segmentation_dataset\\images\\000000064.png',
#  '../segmentation_dataset\\images\\000000065.png',
#  '../segmentation_dataset\\images\\000000066.png',
#  '../segmentation_dataset\\images\\000000067.png',
#  '../segmentation_dataset\\images\\000000068.png',
#  '../segmentation_dataset\\images\\000000069.png',
#  '../segmentation_dataset\\images\\000000070.png',
#  '../segmentation_dataset\\images\\000000071.png',
#  '../segmentation_dataset\\images\\000000072.png',
#  '../segmentation_dataset\\images\\000000073.png',
#  '../segmentation_dataset\\images\\000000074.png',
#  '../segmentation_dataset\\images\\000000075.png',
#  '../segmentation_dataset\\images\\000000076.png',
#  '../segmentation_dataset\\images\\000000077.png',
#  '../segmentation_dataset\\images\\000000078.png',
#  '../segmentation_dataset\\images\\000000079.png',
#  '../segmentation_dataset\\images\\000000080.png',
#  '../segmentation_dataset\\images\\000000081.png',
#  '../segmentation_dataset\\images\\000000082.png',
#  '../segmentation_dataset\\images\\000000083.png',
#  '../segmentation_dataset\\images\\000000084.png',
#  '../segmentation_dataset\\images\\000000085.png',
#  '../segmentation_dataset\\images\\000000086.png',
#  '../segmentation_dataset\\images\\000000087.png',
#  '../segmentation_dataset\\images\\000000088.png',
#  '../segmentation_dataset\\images\\000000089.png',
#  '../segmentation_dataset\\images\\000000090.png',
#  '../segmentation_dataset\\images\\000000091.png',
#  '../segmentation_dataset\\images\\000000092.png',
#  '../segmentation_dataset\\images\\000000093.png',
#  '../segmentation_dataset\\images\\000000094.png',
#  '../segmentation_dataset\\images\\000000095.png',
#  '../segmentation_dataset\\images\\000000096.png',
#  '../segmentation_dataset\\images\\000000097.png',
#  '../segmentation_dataset\\images\\000000098.png',
#  '../segmentation_dataset\\images\\000000099.png',
#  '../segmentation_dataset\\images\\000000100.png',
#  '../segmentation_dataset\\images\\000000101.png',
#  '../segmentation_dataset\\images\\000000102.png',
#  '../segmentation_dataset\\images\\000000103.png',
#  '../segmentation_dataset\\images\\000000104.png',
#  '../segmentation_dataset\\images\\000000105.png',
#  '../segmentation_dataset\\images\\000000106.png',
#  '../segmentation_dataset\\images\\000000107.png',
#  '../segmentation_dataset\\images\\000000108.png',
#  '../segmentation_dataset\\images\\000000109.png',
#  '../segmentation_dataset\\images\\000000110.png',
#  '../segmentation_dataset\\images\\000000111.png',
#  '../segmentation_dataset\\images\\000000112.png',
#  '../segmentation_dataset\\images\\000000113.png',
#  '../segmentation_dataset\\images\\000000114.png',
#  '../segmentation_dataset\\images\\000000115.png',
#  '../segmentation_dataset\\images\\000000116.png',
#  '../segmentation_dataset\\images\\000000117.png',
#  '../segmentation_dataset\\images\\000000118.png',
#  '../segmentation_dataset\\images\\000000119.png',
#  '../segmentation_dataset\\images\\000000120.png',
#  '../segmentation_dataset\\images\\000000121.png',
#  '../segmentation_dataset\\images\\000000122.png',
#  '../segmentation_dataset\\images\\000000123.png',
#  '../segmentation_dataset\\images\\000000124.png',
#  '../segmentation_dataset\\images\\000000125.png',
#  '../segmentation_dataset\\images\\000000126.png',
#  '../segmentation_dataset\\images\\000000127.png',
#  '../segmentation_dataset\\images\\000000128.png',
#  '../segmentation_dataset\\images\\000000129.png',
#  '../segmentation_dataset\\images\\000000130.png',
#  '../segmentation_dataset\\images\\000000131.png',
#  '../segmentation_dataset\\images\\000000132.png',
#  '../segmentation_dataset\\images\\000000133.png',
#  '../segmentation_dataset\\images\\000000134.png',
#  '../segmentation_dataset\\images\\000000135.png',
#  '../segmentation_dataset\\images\\000000136.png',
#  '../segmentation_dataset\\images\\000000137.png',
#  '../segmentation_dataset\\images\\000000138.png',
#  '../segmentation_dataset\\images\\000000139.png',
#  '../segmentation_dataset\\images\\000000140.png',
#  '../segmentation_dataset\\images\\000000141.png',
#  '../segmentation_dataset\\images\\000000142.png',
#  '../segmentation_dataset\\images\\000000143.png',
#  '../segmentation_dataset\\images\\000000144.png',
#  '../segmentation_dataset\\images\\000000145.png',
#  '../segmentation_dataset\\images\\000000146.png',
#  '../segmentation_dataset\\images\\000000147.png',
#  '../segmentation_dataset\\images\\000000148.png',
#  '../segmentation_dataset\\images\\000000149.png',
#  '../segmentation_dataset\\images\\000000150.png',
#  '../segmentation_dataset\\images\\000000151.png',
#  '../segmentation_dataset\\images\\000000152.png',
#  '../segmentation_dataset\\images\\000000153.png',
#  '../segmentation_dataset\\images\\000000154.png',
#  '../segmentation_dataset\\images\\000000155.png',
#  '../segmentation_dataset\\images\\000000156.png',
#  '../segmentation_dataset\\images\\000000157.png',
#  '../segmentation_dataset\\images\\000000158.png',
#  '../segmentation_dataset\\images\\000000159.png',
#  '../segmentation_dataset\\images\\000000160.png',
#  '../segmentation_dataset\\images\\000000161.png',
#  '../segmentation_dataset\\images\\000000162.png',
#  '../segmentation_dataset\\images\\000000163.png',
#  '../segmentation_dataset\\images\\000000164.png',
#  '../segmentation_dataset\\images\\000000165.png',
#  '../segmentation_dataset\\images\\000000166.png',
#  '../segmentation_dataset\\images\\000000167.png',
#  '../segmentation_dataset\\images\\000000168.png',
#  '../segmentation_dataset\\images\\000000169.png',
#  '../segmentation_dataset\\images\\000000170.png',
#  '../segmentation_dataset\\images\\000000171.png',
#  '../segmentation_dataset\\images\\000000172.png',
#  '../segmentation_dataset\\images\\000000173.png',
#  '../segmentation_dataset\\images\\000000174.png',
#  '../segmentation_dataset\\images\\000000175.png',
#  '../segmentation_dataset\\images\\000000176.png',
#  '../segmentation_dataset\\images\\000000177.png',
#  '../segmentation_dataset\\images\\000000178.png',
#  '../segmentation_dataset\\images\\000000179.png',
#  '../segmentation_dataset\\images\\000000180.png',
#  '../segmentation_dataset\\images\\000000181.png',
#  '../segmentation_dataset\\images\\000000182.png',
#  '../segmentation_dataset\\images\\000000183.png',
#  '../segmentation_dataset\\images\\000000184.png',
#  '../segmentation_dataset\\images\\000000185.png',
#  '../segmentation_dataset\\images\\000000186.png',
#  '../segmentation_dataset\\images\\000000187.png',
#  '../segmentation_dataset\\images\\000000188.png',
#  '../segmentation_dataset\\images\\000000189.png',
#  '../segmentation_dataset\\images\\000000190.png',
#  '../segmentation_dataset\\images\\000000191.png',
#  '../segmentation_dataset\\images\\000000192.png',
#  '../segmentation_dataset\\images\\000000193.png',
#  '../segmentation_dataset\\images\\000000194.png',
#  '../segmentation_dataset\\images\\000000195.png',
#  '../segmentation_dataset\\images\\000000196.png',
#  '../segmentation_dataset\\images\\000000197.png',
#  '../segmentation_dataset\\images\\000000198.png',
#  '../segmentation_dataset\\images\\000000199.png',
#  '../segmentation_dataset\\images\\000000200.png',
#  '../segmentation_dataset\\images\\000000201.png',
#  '../segmentation_dataset\\images\\000000202.png',
#  '../segmentation_dataset\\images\\000000203.png',
#  '../segmentation_dataset\\images\\000000204.png',
#  '../segmentation_dataset\\images\\000000205.png',
#  '../segmentation_dataset\\images\\000000206.png',
#  '../segmentation_dataset\\images\\000000207.png',
#  '../segmentation_dataset\\images\\000000208.png',
#  '../segmentation_dataset\\images\\000000209.png',
#  '../segmentation_dataset\\images\\000000210.png',
#  '../segmentation_dataset\\images\\000000211.png',
#  '../segmentation_dataset\\images\\000000212.png',
#  '../segmentation_dataset\\images\\000000213.png',
#  '../segmentation_dataset\\images\\000000214.png',
#  '../segmentation_dataset\\images\\000000215.png',
#  '../segmentation_dataset\\images\\000000216.png',
#  '../segmentation_dataset\\images\\000000217.png',
#  '../segmentation_dataset\\images\\000000218.png',
#  '../segmentation_dataset\\images\\000000219.png',
#  '../segmentation_dataset\\images\\000000220.png',
#  '../segmentation_dataset\\images\\000000221.png',
#  '../segmentation_dataset\\images\\000000222.png',
#  '../segmentation_dataset\\images\\000000223.png',
#  '../segmentation_dataset\\images\\000000224.png',
#  '../segmentation_dataset\\images\\000000225.png',
#  '../segmentation_dataset\\images\\000000226.png',
#  '../segmentation_dataset\\images\\000000227.png',
#  '../segmentation_dataset\\images\\000000228.png',
#  '../segmentation_dataset\\images\\000000229.png',
#  '../segmentation_dataset\\images\\000000230.png',
#  '../segmentation_dataset\\images\\000000231.png',
#  '../segmentation_dataset\\images\\000000232.png',
#  '../segmentation_dataset\\images\\000000233.png',
#  '../segmentation_dataset\\images\\000000234.png',
#  '../segmentation_dataset\\images\\000000235.png',
#  '../segmentation_dataset\\images\\000000236.png',
#  '../segmentation_dataset\\images\\000000237.png',
#  '../segmentation_dataset\\images\\000000238.png',
#  '../segmentation_dataset\\images\\000000239.png',
#  '../segmentation_dataset\\images\\000000240.png',
#  '../segmentation_dataset\\images\\000000241.png',
#  '../segmentation_dataset\\images\\000000242.png',
#  '../segmentation_dataset\\images\\000000243.png',
#  '../segmentation_dataset\\images\\000000244.png',
#  '../segmentation_dataset\\images\\000000245.png',
#  '../segmentation_dataset\\images\\000000246.png',
#  '../segmentation_dataset\\images\\000000247.png',
#  '../segmentation_dataset\\images\\000000248.png',
#  '../segmentation_dataset\\images\\000000249.png',
#  '../segmentation_dataset\\images\\000000250.png',
#  '../segmentation_dataset\\images\\000000251.png',
#  '../segmentation_dataset\\images\\000000252.png',
#  '../segmentation_dataset\\images\\000000253.png',
#  '../segmentation_dataset\\images\\000000254.png',
#  '../segmentation_dataset\\images\\000000255.png',
#  '../segmentation_dataset\\images\\000000256.png',
#  '../segmentation_dataset\\images\\000000257.png',
#  '../segmentation_dataset\\images\\000000258.png',
#  '../segmentation_dataset\\images\\000000259.png',
#  '../segmentation_dataset\\images\\000000260.png',
#  '../segmentation_dataset\\images\\000000261.png',
#  '../segmentation_dataset\\images\\000000262.png',
#  '../segmentation_dataset\\images\\000000263.png',
#  '../segmentation_dataset\\images\\000000264.png',
#  '../segmentation_dataset\\images\\000000265.png',
#  '../segmentation_dataset\\images\\000000266.png',
#  '../segmentation_dataset\\images\\000000267.png',
#  '../segmentation_dataset\\images\\000000268.png',
#  '../segmentation_dataset\\images\\000000269.png',
#  '../segmentation_dataset\\images\\000000270.png',
#  '../segmentation_dataset\\images\\000000271.png',
#  '../segmentation_dataset\\images\\000000272.png',
#  '../segmentation_dataset\\images\\000000273.png',
#  '../segmentation_dataset\\images\\000000274.png',
#  '../segmentation_dataset\\images\\000000275.png',
#  '../segmentation_dataset\\images\\000000276.png',
#  '../segmentation_dataset\\images\\000000277.png',
#  '../segmentation_dataset\\images\\000000278.png',
#  '../segmentation_dataset\\images\\000000279.png',
#  '../segmentation_dataset\\images\\000000280.png',
#  '../segmentation_dataset\\images\\000000281.png',
#  '../segmentation_dataset\\images\\000000282.png',
#  '../segmentation_dataset\\images\\000000283.png',
#  '../segmentation_dataset\\images\\000000284.png',
#  '../segmentation_dataset\\images\\000000285.png',
#  '../segmentation_dataset\\images\\000000286.png',
#  '../segmentation_dataset\\images\\000000287.png',
#  '../segmentation_dataset\\images\\000000288.png',
#  '../segmentation_dataset\\images\\000000289.png',
#  '../segmentation_dataset\\images\\000000290.png',
#  '../segmentation_dataset\\images\\000000291.png',
#  '../segmentation_dataset\\images\\000000292.png',
#  '../segmentation_dataset\\images\\000000293.png',
#  '../segmentation_dataset\\images\\000000294.png',
#  '../segmentation_dataset\\images\\000000295.png',
#  '../segmentation_dataset\\images\\000000296.png',
#  '../segmentation_dataset\\images\\000000297.png',
#  '../segmentation_dataset\\images\\000000298.png',
#  '../segmentation_dataset\\images\\000000299.png',
#  '../segmentation_dataset\\images\\000000300.png',
#  '../segmentation_dataset\\images\\000000301.png',
#  '../segmentation_dataset\\images\\000000302.png',
#  '../segmentation_dataset\\images\\000000303.png',
#  '../segmentation_dataset\\images\\000000304.png',
#  '../segmentation_dataset\\images\\000000305.png',
#  '../segmentation_dataset\\images\\000000306.png',
#  '../segmentation_dataset\\images\\000000307.png',
#  '../segmentation_dataset\\images\\000000308.png',
#  '../segmentation_dataset\\images\\000000309.png',
#  '../segmentation_dataset\\images\\000000310.png',
#  '../segmentation_dataset\\images\\000000311.png',
#  '../segmentation_dataset\\images\\000000312.png',
#  '../segmentation_dataset\\images\\000000313.png',
#  '../segmentation_dataset\\images\\000000314.png',
#  '../segmentation_dataset\\images\\000000315.png',
#  '../segmentation_dataset\\images\\000000316.png',
#  '../segmentation_dataset\\images\\000000317.png',
#  '../segmentation_dataset\\images\\000000318.png',
#  '../segmentation_dataset\\images\\000000319.png',
#  '../segmentation_dataset\\images\\000000320.png',
#  '../segmentation_dataset\\images\\000000321.png',
#  '../segmentation_dataset\\images\\000000322.png',
#  '../segmentation_dataset\\images\\000000323.png',
#  '../segmentation_dataset\\images\\000000324.png',
#  '../segmentation_dataset\\images\\000000325.png',
#  '../segmentation_dataset\\images\\000000326.png',
#  '../segmentation_dataset\\images\\000000327.png',
#  '../segmentation_dataset\\images\\000000328.png',
#  '../segmentation_dataset\\images\\000000329.png',
#  '../segmentation_dataset\\images\\000000330.png',
#  '../segmentation_dataset\\images\\000000331.png',
#  '../segmentation_dataset\\images\\000000332.png',
#  '../segmentation_dataset\\images\\000000333.png',
#  '../segmentation_dataset\\images\\000000334.png',
#  '../segmentation_dataset\\images\\000000335.png',
#  '../segmentation_dataset\\images\\000000336.png',
#  '../segmentation_dataset\\images\\000000337.png',
#  '../segmentation_dataset\\images\\000000338.png',
#  '../segmentation_dataset\\images\\000000339.png',
#  '../segmentation_dataset\\images\\000000340.png',
#  '../segmentation_dataset\\images\\000000341.png',
#  '../segmentation_dataset\\images\\000000342.png',
#  '../segmentation_dataset\\images\\000000343.png',
#  '../segmentation_dataset\\images\\000000344.png',
#  '../segmentation_dataset\\images\\000000345.png',
#  '../segmentation_dataset\\images\\000000346.png',
#  '../segmentation_dataset\\images\\000000347.png',
#  '../segmentation_dataset\\images\\000000348.png',
#  '../segmentation_dataset\\images\\000000349.png',
#  '../segmentation_dataset\\images\\000000350.png',
#  '../segmentation_dataset\\images\\000000351.png',
#  '../segmentation_dataset\\images\\000000352.png',
#  '../segmentation_dataset\\images\\000000353.png',
#  '../segmentation_dataset\\images\\000000354.png',
#  '../segmentation_dataset\\images\\000000355.png',
#  '../segmentation_dataset\\images\\000000356.png',
#  '../segmentation_dataset\\images\\000000357.png',
#  '../segmentation_dataset\\images\\000000358.png',
#  '../segmentation_dataset\\images\\000000359.png',
#  '../segmentation_dataset\\images\\000000360.png',
#  '../segmentation_dataset\\images\\000000361.png',
#  '../segmentation_dataset\\images\\000000362.png',
#  '../segmentation_dataset\\images\\000000363.png',
#  '../segmentation_dataset\\images\\000000364.png',
#  '../segmentation_dataset\\images\\000000365.png',
#  '../segmentation_dataset\\images\\000000366.png',
#  '../segmentation_dataset\\images\\000000367.png',
#  '../segmentation_dataset\\images\\000000368.png',
#  '../segmentation_dataset\\images\\000000369.png',
#  '../segmentation_dataset\\images\\000000370.png',
#  '../segmentation_dataset\\images\\000000371.png',
#  '../segmentation_dataset\\images\\000000372.png',
#  '../segmentation_dataset\\images\\000000373.png',
#  '../segmentation_dataset\\images\\000000374.png',
#  '../segmentation_dataset\\images\\000000375.png',
#  '../segmentation_dataset\\images\\000000376.png',
#  '../segmentation_dataset\\images\\000000377.png',
#  '../segmentation_dataset\\images\\000000378.png',
#  '../segmentation_dataset\\images\\000000379.png',
#  '../segmentation_dataset\\images\\000000380.png',
#  '../segmentation_dataset\\images\\000000381.png',
#  '../segmentation_dataset\\images\\000000382.png',
#  '../segmentation_dataset\\images\\000000383.png',
#  '../segmentation_dataset\\images\\000000384.png',
#  '../segmentation_dataset\\images\\000000385.png',
#  '../segmentation_dataset\\images\\000000386.png',
#  '../segmentation_dataset\\images\\000000387.png',
#  '../segmentation_dataset\\images\\000000388.png',
#  '../segmentation_dataset\\images\\000000389.png',
#  '../segmentation_dataset\\images\\000000390.png',
#  '../segmentation_dataset\\images\\000000391.png',
#  '../segmentation_dataset\\images\\000000392.png',
#  '../segmentation_dataset\\images\\000000393.png',
#  '../segmentation_dataset\\images\\000000394.png',
#  '../segmentation_dataset\\images\\000000395.png',
#  '../segmentation_dataset\\images\\000000396.png',
#  '../segmentation_dataset\\images\\000000397.png',
#  '../segmentation_dataset\\images\\000000398.png',
#  '../segmentation_dataset\\images\\000000399.png',
#  '../segmentation_dataset\\images\\000000400.png',
#  '../segmentation_dataset\\images\\000000401.png',
#  '../segmentation_dataset\\images\\000000402.png',
#  '../segmentation_dataset\\images\\000000403.png',
#  '../segmentation_dataset\\images\\000000404.png',
#  '../segmentation_dataset\\images\\000000405.png',
#  '../segmentation_dataset\\images\\000000406.png',
#  '../segmentation_dataset\\images\\000000407.png',
#  '../segmentation_dataset\\images\\000000408.png',
#  '../segmentation_dataset\\images\\000000409.png',
#  '../segmentation_dataset\\images\\000000410.png',
#  '../segmentation_dataset\\images\\000000411.png',
#  '../segmentation_dataset\\images\\000000412.png',
#  '../segmentation_dataset\\images\\000000413.png',
#  '../segmentation_dataset\\images\\000000414.png',
#  '../segmentation_dataset\\images\\000000415.png',
#  '../segmentation_dataset\\images\\000000416.png',
#  '../segmentation_dataset\\images\\000000417.png',
#  '../segmentation_dataset\\images\\000000418.png',
#  '../segmentation_dataset\\images\\000000419.png',
#  '../segmentation_dataset\\images\\000000420.png',
#  '../segmentation_dataset\\images\\000000421.png',
#  '../segmentation_dataset\\images\\000000422.png',
#  '../segmentation_dataset\\images\\000000423.png',
#  '../segmentation_dataset\\images\\000000424.png',
#  '../segmentation_dataset\\images\\000000425.png',
#  '../segmentation_dataset\\images\\000000426.png',
#  '../segmentation_dataset\\images\\000000427.png',
#  '../segmentation_dataset\\images\\000000428.png',
#  '../segmentation_dataset\\images\\000000429.png',
#  '../segmentation_dataset\\images\\000000430.png',
#  '../segmentation_dataset\\images\\000000431.png',
#  '../segmentation_dataset\\images\\000000432.png',
#  '../segmentation_dataset\\images\\000000433.png',
#  '../segmentation_dataset\\images\\000000434.png',
#  '../segmentation_dataset\\images\\000000435.png',
#  '../segmentation_dataset\\images\\000000436.png',
#  '../segmentation_dataset\\images\\000000437.png',
#  '../segmentation_dataset\\images\\000000438.png',
#  '../segmentation_dataset\\images\\000000439.png',
#  '../segmentation_dataset\\images\\000000440.png',
#  '../segmentation_dataset\\images\\000000441.png',
#  '../segmentation_dataset\\images\\000000442.png',
#  '../segmentation_dataset\\images\\000000443.png',
#  '../segmentation_dataset\\images\\000000444.png',
#  '../segmentation_dataset\\images\\000000445.png',
#  '../segmentation_dataset\\images\\000000446.png',
#  '../segmentation_dataset\\images\\000000447.png',
#  '../segmentation_dataset\\images\\000000448.png',
#  '../segmentation_dataset\\images\\000000449.png',
#  '../segmentation_dataset\\images\\000000450.png',
#  '../segmentation_dataset\\images\\000000451.png',
#  '../segmentation_dataset\\images\\000000452.png',
#  '../segmentation_dataset\\images\\000000453.png',
#  '../segmentation_dataset\\images\\000000454.png',
#  '../segmentation_dataset\\images\\000000455.png',
#  '../segmentation_dataset\\images\\000000456.png',
#  '../segmentation_dataset\\images\\000000457.png',
#  '../segmentation_dataset\\images\\000000458.png',
#  '../segmentation_dataset\\images\\000000459.png',
#  '../segmentation_dataset\\images\\000000460.png',
#  '../segmentation_dataset\\images\\000000461.png',
#  '../segmentation_dataset\\images\\000000462.png',
#  '../segmentation_dataset\\images\\000000463.png',
#  '../segmentation_dataset\\images\\000000464.png',
#  '../segmentation_dataset\\images\\000000465.png',
#  '../segmentation_dataset\\images\\000000466.png',
#  '../segmentation_dataset\\images\\000000467.png',
#  '../segmentation_dataset\\images\\000000468.png',
#  '../segmentation_dataset\\images\\000000469.png',
#  '../segmentation_dataset\\images\\000000470.png',
#  '../segmentation_dataset\\images\\000000471.png',
#  '../segmentation_dataset\\images\\000000472.png',
#  '../segmentation_dataset\\images\\000000473.png',
#  '../segmentation_dataset\\images\\000000474.png',
#  '../segmentation_dataset\\images\\000000475.png',
#  '../segmentation_dataset\\images\\000000476.png',
#  '../segmentation_dataset\\images\\000000477.png',
#  '../segmentation_dataset\\images\\000000478.png',
#  '../segmentation_dataset\\images\\000000479.png',
#  '../segmentation_dataset\\images\\000000480.png',
#  '../segmentation_dataset\\images\\000000481.png',
#  '../segmentation_dataset\\images\\000000482.png',
#  '../segmentation_dataset\\images\\000000483.png',
#  '../segmentation_dataset\\images\\000000484.png',
#  '../segmentation_dataset\\images\\000000485.png',
#  '../segmentation_dataset\\images\\000000486.png',
#  '../segmentation_dataset\\images\\000000487.png',
#  '../segmentation_dataset\\images\\000000488.png',
#  '../segmentation_dataset\\images\\000000489.png',
#  '../segmentation_dataset\\images\\000000490.png',
#  '../segmentation_dataset\\images\\000000491.png',
#  '../segmentation_dataset\\images\\000000492.png',
#  '../segmentation_dataset\\images\\000000493.png',
#  '../segmentation_dataset\\images\\000000494.png',
#  '../segmentation_dataset\\images\\000000495.png',
#  '../segmentation_dataset\\images\\000000496.png',
#  '../segmentation_dataset\\images\\000000497.png',
#  '../segmentation_dataset\\images\\000000498.png',
#  '../segmentation_dataset\\images\\000000499.png',
#  '../segmentation_dataset\\images\\000000500.png',
#  '../segmentation_dataset\\images\\000000501.png',
#  '../segmentation_dataset\\images\\000000502.png',
#  '../segmentation_dataset\\images\\000000503.png',
#  '../segmentation_dataset\\images\\000000504.png',
#  '../segmentation_dataset\\images\\000000505.png',
#  '../segmentation_dataset\\images\\000000506.png',
#  '../segmentation_dataset\\images\\000000507.png',
#  '../segmentation_dataset\\images\\000000508.png',
#  '../segmentation_dataset\\images\\000000509.png',
#  '../segmentation_dataset\\images\\000000510.png',
#  '../segmentation_dataset\\images\\000000511.png',
#  '../segmentation_dataset\\images\\000000512.png',
#  '../segmentation_dataset\\images\\000000513.png',
#  '../segmentation_dataset\\images\\000000514.png',
#  '../segmentation_dataset\\images\\000000515.png',
#  '../segmentation_dataset\\images\\000000516.png',
#  '../segmentation_dataset\\images\\000000517.png',
#  '../segmentation_dataset\\images\\000000518.png',
#  '../segmentation_dataset\\images\\000000519.png',
#  '../segmentation_dataset\\images\\000000520.png',
#  '../segmentation_dataset\\images\\000000521.png',
#  '../segmentation_dataset\\images\\000000522.png',
#  '../segmentation_dataset\\images\\000000523.png',
#  '../segmentation_dataset\\images\\000000524.png',
#  '../segmentation_dataset\\images\\000000525.png',
#  '../segmentation_dataset\\images\\000000526.png',
#  '../segmentation_dataset\\images\\000000527.png',
#  '../segmentation_dataset\\images\\000000528.png',
#  '../segmentation_dataset\\images\\000000529.png',
#  '../segmentation_dataset\\images\\000000530.png',
#  '../segmentation_dataset\\images\\000000531.png',
#  '../segmentation_dataset\\images\\000000532.png',
#  '../segmentation_dataset\\images\\000000533.png',
#  '../segmentation_dataset\\images\\000000534.png',
#  '../segmentation_dataset\\images\\000000535.png',
#  '../segmentation_dataset\\images\\000000536.png',
#  '../segmentation_dataset\\images\\000000537.png',
#  '../segmentation_dataset\\images\\000000538.png',
#  '../segmentation_dataset\\images\\000000539.png',
#  '../segmentation_dataset\\images\\000000540.png',
#  '../segmentation_dataset\\images\\000000541.png',
#  '../segmentation_dataset\\images\\000000542.png',
#  '../segmentation_dataset\\images\\000000543.png',
#  '../segmentation_dataset\\images\\000000544.png',
#  '../segmentation_dataset\\images\\000000545.png',
#  '../segmentation_dataset\\images\\000000546.png',
#  '../segmentation_dataset\\images\\000000547.png',
#  '../segmentation_dataset\\images\\000000548.png',
#  '../segmentation_dataset\\images\\000000549.png',
#  '../segmentation_dataset\\images\\000000550.png',
#  '../segmentation_dataset\\images\\000000551.png',
#  '../segmentation_dataset\\images\\000000552.png',
#  '../segmentation_dataset\\images\\000000553.png',
#  '../segmentation_dataset\\images\\000000554.png',
#  '../segmentation_dataset\\images\\000000555.png',
#  '../segmentation_dataset\\images\\000000556.png',
#  '../segmentation_dataset\\images\\000000557.png',
#  '../segmentation_dataset\\images\\000000558.png',
#  '../segmentation_dataset\\images\\000000559.png',
#  '../segmentation_dataset\\images\\000000560.png',
#  '../segmentation_dataset\\images\\000000561.png',
#  '../segmentation_dataset\\images\\000000562.png',
#  '../segmentation_dataset\\images\\000000563.png',
#  '../segmentation_dataset\\images\\000000564.png',
#  '../segmentation_dataset\\images\\000000565.png',
#  '../segmentation_dataset\\images\\000000566.png',
#  '../segmentation_dataset\\images\\000000567.png',
#  '../segmentation_dataset\\images\\000000568.png',
#  '../segmentation_dataset\\images\\000000569.png',
#  '../segmentation_dataset\\images\\000000570.png',
#  '../segmentation_dataset\\images\\000000571.png',
#  '../segmentation_dataset\\images\\000000572.png',
#  '../segmentation_dataset\\images\\000000573.png',
#  '../segmentation_dataset\\images\\000000574.png',
#  '../segmentation_dataset\\images\\000000575.png',
#  '../segmentation_dataset\\images\\000000576.png',
#  '../segmentation_dataset\\images\\000000577.png',
#  '../segmentation_dataset\\images\\000000578.png',
#  '../segmentation_dataset\\images\\000000579.png',
#  '../segmentation_dataset\\images\\000000580.png',
#  '../segmentation_dataset\\images\\000000581.png',
#  '../segmentation_dataset\\images\\000000582.png',
#  '../segmentation_dataset\\images\\000000583.png',
#  '../segmentation_dataset\\images\\000000584.png',
#  '../segmentation_dataset\\images\\000000585.png',
#  '../segmentation_dataset\\images\\000000586.png',
#  '../segmentation_dataset\\images\\000000587.png',
#  '../segmentation_dataset\\images\\000000588.png',
#  '../segmentation_dataset\\images\\000000589.png',
#  '../segmentation_dataset\\images\\000000590.png',
#  '../segmentation_dataset\\images\\000000591.png',
#  '../segmentation_dataset\\images\\000000592.png',
#  '../segmentation_dataset\\images\\000000593.png',
#  '../segmentation_dataset\\images\\000000594.png',
#  '../segmentation_dataset\\images\\000000595.png',
#  '../segmentation_dataset\\images\\000000596.png',
#  '../segmentation_dataset\\images\\000000597.png',
#  '../segmentation_dataset\\images\\000000598.png',
#  '../segmentation_dataset\\images\\000000599.png',
#  '../segmentation_dataset\\images\\000000600.png',
#  '../segmentation_dataset\\images\\000000601.png',
#  '../segmentation_dataset\\images\\000000602.png',
#  '../segmentation_dataset\\images\\000000603.png',
#  '../segmentation_dataset\\images\\000000604.png',
#  '../segmentation_dataset\\images\\000000605.png',
#  '../segmentation_dataset\\images\\000000606.png',
#  '../segmentation_dataset\\images\\000000607.png',
#  '../segmentation_dataset\\images\\000000608.png',
#  '../segmentation_dataset\\images\\000000609.png',
#  '../segmentation_dataset\\images\\000000610.png',
#  '../segmentation_dataset\\images\\000000611.png',
#  '../segmentation_dataset\\images\\000000612.png',
#  '../segmentation_dataset\\images\\000000613.png',
#  '../segmentation_dataset\\images\\000000614.png',
#  '../segmentation_dataset\\images\\000000615.png',
#  '../segmentation_dataset\\images\\000000616.png',
#  '../segmentation_dataset\\images\\000000617.png',
#  '../segmentation_dataset\\images\\000000618.png',
#  '../segmentation_dataset\\images\\000000619.png',
#  '../segmentation_dataset\\images\\000000620.png',
#  '../segmentation_dataset\\images\\000000621.png',
#  '../segmentation_dataset\\images\\000000622.png',
#  '../segmentation_dataset\\images\\000000623.png',
#  '../segmentation_dataset\\images\\000000624.png',
#  '../segmentation_dataset\\images\\000000625.png',
#  '../segmentation_dataset\\images\\000000626.png',
#  '../segmentation_dataset\\images\\000000627.png',
#  '../segmentation_dataset\\images\\000000628.png',
#  '../segmentation_dataset\\images\\000000629.png',
#  '../segmentation_dataset\\images\\000000630.png',
#  '../segmentation_dataset\\images\\000000631.png',
#  '../segmentation_dataset\\images\\000000632.png',
#  '../segmentation_dataset\\images\\000000633.png',
#  '../segmentation_dataset\\images\\000000634.png',
#  '../segmentation_dataset\\images\\000000635.png',
#  '../segmentation_dataset\\images\\000000636.png',
#  '../segmentation_dataset\\images\\000000637.png',
#  '../segmentation_dataset\\images\\000000638.png',
#  '../segmentation_dataset\\images\\000000639.png',
#  '../segmentation_dataset\\images\\000000640.png',
#  '../segmentation_dataset\\images\\000000641.png',
#  '../segmentation_dataset\\images\\000000642.png',
#  '../segmentation_dataset\\images\\000000643.png',
#  '../segmentation_dataset\\images\\000000644.png',
#  '../segmentation_dataset\\images\\000000645.png',
#  '../segmentation_dataset\\images\\000000646.png',
#  '../segmentation_dataset\\images\\000000647.png',
#  '../segmentation_dataset\\images\\000000648.png',
#  '../segmentation_dataset\\images\\000000649.png',
#  '../segmentation_dataset\\images\\000000650.png',
#  '../segmentation_dataset\\images\\000000651.png',
#  '../segmentation_dataset\\images\\000000652.png',
#  '../segmentation_dataset\\images\\000000653.png',
#  '../segmentation_dataset\\images\\000000654.png',
#  '../segmentation_dataset\\images\\000000655.png',
#  '../segmentation_dataset\\images\\000000656.png',
#  '../segmentation_dataset\\images\\000000657.png',
#  '../segmentation_dataset\\images\\000000658.png',
#  '../segmentation_dataset\\images\\000000659.png',
#  '../segmentation_dataset\\images\\000000660.png',
#  '../segmentation_dataset\\images\\000000661.png',
#  '../segmentation_dataset\\images\\000000662.png',
#  '../segmentation_dataset\\images\\000000663.png',
#  '../segmentation_dataset\\images\\000000664.png',
#  '../segmentation_dataset\\images\\000000665.png',
#  '../segmentation_dataset\\images\\000000666.png',
#  '../segmentation_dataset\\images\\000000667.png',
#  '../segmentation_dataset\\images\\000000668.png',
#  '../segmentation_dataset\\images\\000000669.png',
#  '../segmentation_dataset\\images\\000000670.png',
#  '../segmentation_dataset\\images\\000000671.png',
#  '../segmentation_dataset\\images\\000000672.png',
#  '../segmentation_dataset\\images\\000000673.png',
#  '../segmentation_dataset\\images\\000000674.png',
#  '../segmentation_dataset\\images\\000000675.png',
#  '../segmentation_dataset\\images\\000000676.png',
#  '../segmentation_dataset\\images\\000000677.png',
#  '../segmentation_dataset\\images\\000000678.png',
#  '../segmentation_dataset\\images\\000000679.png',
#  '../segmentation_dataset\\images\\000000680.png',
#  '../segmentation_dataset\\images\\000000681.png',
#  '../segmentation_dataset\\images\\000000682.png',
#  '../segmentation_dataset\\images\\000000683.png',
#  '../segmentation_dataset\\images\\000000684.png',
#  '../segmentation_dataset\\images\\000000685.png',
#  '../segmentation_dataset\\images\\000000686.png',
#  '../segmentation_dataset\\images\\000000687.png',
#  '../segmentation_dataset\\images\\000000688.png',
#  '../segmentation_dataset\\images\\000000689.png',
#  '../segmentation_dataset\\images\\000000690.png',
#  '../segmentation_dataset\\images\\000000691.png',
#  '../segmentation_dataset\\images\\000000692.png',
#  '../segmentation_dataset\\images\\000000693.png',
#  '../segmentation_dataset\\images\\000000694.png',
#  '../segmentation_dataset\\images\\000000695.png',
#  '../segmentation_dataset\\images\\000000696.png',
#  '../segmentation_dataset\\images\\000000697.png',
#  '../segmentation_dataset\\images\\000000698.png',
#  '../segmentation_dataset\\images\\000000699.png',
#  '../segmentation_dataset\\images\\000000700.png',
#  '../segmentation_dataset\\images\\000000701.png',
#  '../segmentation_dataset\\images\\000000702.png',
#  '../segmentation_dataset\\images\\000000703.png',
#  '../segmentation_dataset\\images\\000000704.png',
#  '../segmentation_dataset\\images\\000000705.png',
#  '../segmentation_dataset\\images\\000000706.png',
#  '../segmentation_dataset\\images\\000000707.png',
#  '../segmentation_dataset\\images\\000000708.png',
#  '../segmentation_dataset\\images\\000000709.png',
#  '../segmentation_dataset\\images\\000000710.png',
#  '../segmentation_dataset\\images\\000000711.png',
#  '../segmentation_dataset\\images\\000000712.png',
#  '../segmentation_dataset\\images\\000000713.png',
#  '../segmentation_dataset\\images\\000000714.png',
#  '../segmentation_dataset\\images\\000000715.png',
#  '../segmentation_dataset\\images\\000000716.png',
#  '../segmentation_dataset\\images\\000000717.png',
#  '../segmentation_dataset\\images\\000000718.png',
#  '../segmentation_dataset\\images\\000000719.png',
#  '../segmentation_dataset\\images\\000000720.png',
#  '../segmentation_dataset\\images\\000000721.png',
#  '../segmentation_dataset\\images\\000000722.png',
#  '../segmentation_dataset\\images\\000000723.png',
#  '../segmentation_dataset\\images\\000000724.png',
#  '../segmentation_dataset\\images\\000000725.png',
#  '../segmentation_dataset\\images\\000000726.png',
#  '../segmentation_dataset\\images\\000000727.png',
#  '../segmentation_dataset\\images\\000000728.png',
#  '../segmentation_dataset\\images\\000000729.png',
#  '../segmentation_dataset\\images\\000000730.png',
#  '../segmentation_dataset\\images\\000000731.png',
#  '../segmentation_dataset\\images\\000000732.png',
#  '../segmentation_dataset\\images\\000000733.png',
#  '../segmentation_dataset\\images\\000000734.png',
#  '../segmentation_dataset\\images\\000000735.png',
#  '../segmentation_dataset\\images\\000000736.png',
#  '../segmentation_dataset\\images\\000000737.png',
#  '../segmentation_dataset\\images\\000000738.png',
#  '../segmentation_dataset\\images\\000000739.png',
#  '../segmentation_dataset\\images\\000000740.png',
#  '../segmentation_dataset\\images\\000000741.png',
#  '../segmentation_dataset\\images\\000000742.png',
#  '../segmentation_dataset\\images\\000000743.png',
#  '../segmentation_dataset\\images\\000000744.png',
#  '../segmentation_dataset\\images\\000000745.png',
#  '../segmentation_dataset\\images\\000000746.png',
#  '../segmentation_dataset\\images\\000000747.png',
#  '../segmentation_dataset\\images\\000000748.png',
#  '../segmentation_dataset\\images\\000000749.png',
#  '../segmentation_dataset\\images\\000000750.png',
#  '../segmentation_dataset\\images\\000000751.png',
#  '../segmentation_dataset\\images\\000000752.png',
#  '../segmentation_dataset\\images\\000000753.png',
#  '../segmentation_dataset\\images\\000000754.png',
#  '../segmentation_dataset\\images\\000000755.png',
#  '../segmentation_dataset\\images\\000000756.png',
#  '../segmentation_dataset\\images\\000000757.png',
#  '../segmentation_dataset\\images\\000000758.png',
#  '../segmentation_dataset\\images\\000000759.png',
#  '../segmentation_dataset\\images\\000000760.png',
#  '../segmentation_dataset\\images\\000000761.png',
#  '../segmentation_dataset\\images\\000000762.png',
#  '../segmentation_dataset\\images\\000000763.png',
#  '../segmentation_dataset\\images\\000000764.png',
#  '../segmentation_dataset\\images\\000000765.png',
#  '../segmentation_dataset\\images\\000000766.png',
#  '../segmentation_dataset\\images\\000000767.png',
#  '../segmentation_dataset\\images\\000000768.png',
#  '../segmentation_dataset\\images\\000000769.png',
#  '../segmentation_dataset\\images\\000000770.png',
#  '../segmentation_dataset\\images\\000000771.png',
#  '../segmentation_dataset\\images\\000000772.png',
#  '../segmentation_dataset\\images\\000000773.png',
#  '../segmentation_dataset\\images\\000000774.png',
#  '../segmentation_dataset\\images\\000000775.png',
#  '../segmentation_dataset\\images\\000000776.png',
#  '../segmentation_dataset\\images\\000000777.png',
#  '../segmentation_dataset\\images\\000000778.png',
#  '../segmentation_dataset\\images\\000000779.png',
#  '../segmentation_dataset\\images\\000000780.png',
#  '../segmentation_dataset\\images\\000000781.png',
#  '../segmentation_dataset\\images\\000000782.png',
#  '../segmentation_dataset\\images\\000000783.png',
#  '../segmentation_dataset\\images\\000000784.png',
#  '../segmentation_dataset\\images\\000000785.png',
#  '../segmentation_dataset\\images\\000000786.png',
#  '../segmentation_dataset\\images\\000000787.png',
#  '../segmentation_dataset\\images\\000000788.png',
#  '../segmentation_dataset\\images\\000000789.png',
#  '../segmentation_dataset\\images\\000000790.png',
#  '../segmentation_dataset\\images\\000000791.png',
#  '../segmentation_dataset\\images\\000000792.png',
#  '../segmentation_dataset\\images\\000000793.png',
#  '../segmentation_dataset\\images\\000000794.png',
#  '../segmentation_dataset\\images\\000000795.png',
#  '../segmentation_dataset\\images\\000000796.png',
#  '../segmentation_dataset\\images\\000000797.png',
#  '../segmentation_dataset\\images\\000000798.png',
#  '../segmentation_dataset\\images\\000000799.png',
#  '../segmentation_dataset\\images\\000000800.png',
#  '../segmentation_dataset\\images\\000000801.png',
#  '../segmentation_dataset\\images\\000000802.png',
#  '../segmentation_dataset\\images\\000000803.png',
#  '../segmentation_dataset\\images\\000000804.png',
#  '../segmentation_dataset\\images\\000000805.png',
#  '../segmentation_dataset\\images\\000000806.png',
#  '../segmentation_dataset\\images\\000000807.png',
#  '../segmentation_dataset\\images\\000000808.png',
#  '../segmentation_dataset\\images\\000000809.png',
#  '../segmentation_dataset\\images\\000000810.png',
#  '../segmentation_dataset\\images\\000000811.png',
#  '../segmentation_dataset\\images\\000000812.png',
#  '../segmentation_dataset\\images\\000000813.png',
#  '../segmentation_dataset\\images\\000000814.png',
#  '../segmentation_dataset\\images\\000000815.png',
#  '../segmentation_dataset\\images\\000000816.png',
#  '../segmentation_dataset\\images\\000000817.png',
#  '../segmentation_dataset\\images\\000000818.png',
#  '../segmentation_dataset\\images\\000000819.png',
#  '../segmentation_dataset\\images\\000000820.png',
#  '../segmentation_dataset\\images\\000000821.png',
#  '../segmentation_dataset\\images\\000000822.png',
#  '../segmentation_dataset\\images\\000000823.png',
#  '../segmentation_dataset\\images\\000000824.png',
#  '../segmentation_dataset\\images\\000000825.png',
#  '../segmentation_dataset\\images\\000000826.png',
#  '../segmentation_dataset\\images\\000000827.png',
#  '../segmentation_dataset\\images\\000000828.png',
#  '../segmentation_dataset\\images\\000000829.png',
#  '../segmentation_dataset\\images\\000000830.png',
#  '../segmentation_dataset\\images\\000000831.png',
#  '../segmentation_dataset\\images\\000000832.png',
#  '../segmentation_dataset\\images\\000000833.png',
#  '../segmentation_dataset\\images\\000000834.png',
#  '../segmentation_dataset\\images\\000000835.png',
#  '../segmentation_dataset\\images\\000000836.png',
#  '../segmentation_dataset\\images\\000000837.png',
#  '../segmentation_dataset\\images\\000000838.png',
#  '../segmentation_dataset\\images\\000000839.png',
#  '../segmentation_dataset\\images\\000000840.png',
#  '../segmentation_dataset\\images\\000000841.png',
#  '../segmentation_dataset\\images\\000000842.png',
#  '../segmentation_dataset\\images\\000000843.png',
#  '../segmentation_dataset\\images\\000000844.png',
#  '../segmentation_dataset\\images\\000000845.png',
#  '../segmentation_dataset\\images\\000000846.png',
#  '../segmentation_dataset\\images\\000000847.png',
#  '../segmentation_dataset\\images\\000000848.png',
#  '../segmentation_dataset\\images\\000000849.png',
#  '../segmentation_dataset\\images\\000000850.png',
#  '../segmentation_dataset\\images\\000000851.png',
#  '../segmentation_dataset\\images\\000000852.png',
#  '../segmentation_dataset\\images\\000000853.png',
#  '../segmentation_dataset\\images\\000000854.png',
#  '../segmentation_dataset\\images\\000000855.png',
#  '../segmentation_dataset\\images\\000000856.png',
#  '../segmentation_dataset\\images\\000000857.png',
#  '../segmentation_dataset\\images\\000000858.png',
#  '../segmentation_dataset\\images\\000000859.png',
#  '../segmentation_dataset\\images\\000000860.png',
#  '../segmentation_dataset\\images\\000000861.png',
#  '../segmentation_dataset\\images\\000000862.png',
#  '../segmentation_dataset\\images\\000000863.png',
#  '../segmentation_dataset\\images\\000000864.png',
#  '../segmentation_dataset\\images\\000000865.png',
#  '../segmentation_dataset\\images\\000000866.png',
#  '../segmentation_dataset\\images\\000000867.png',
#  '../segmentation_dataset\\images\\000000868.png',
#  '../segmentation_dataset\\images\\000000869.png',
#  '../segmentation_dataset\\images\\000000870.png',
#  '../segmentation_dataset\\images\\000000871.png',
#  '../segmentation_dataset\\images\\000000872.png',
#  '../segmentation_dataset\\images\\000000873.png',
#  '../segmentation_dataset\\images\\000000874.png',
#  '../segmentation_dataset\\images\\000000875.png',
#  '../segmentation_dataset\\images\\000000876.png',
#  '../segmentation_dataset\\images\\000000877.png',
#  '../segmentation_dataset\\images\\000000878.png',
#  '../segmentation_dataset\\images\\000000879.png',
#  '../segmentation_dataset\\images\\000000880.png',
#  '../segmentation_dataset\\images\\000000881.png',
#  '../segmentation_dataset\\images\\000000882.png',
#  '../segmentation_dataset\\images\\000000883.png',
#  '../segmentation_dataset\\images\\000000884.png',
#  '../segmentation_dataset\\images\\000000885.png',
#  '../segmentation_dataset\\images\\000000886.png',
#  '../segmentation_dataset\\images\\000000887.png',
#  '../segmentation_dataset\\images\\000000888.png',
#  '../segmentation_dataset\\images\\000000889.png',
#  '../segmentation_dataset\\images\\000000890.png',
#  '../segmentation_dataset\\images\\000000891.png',
#  '../segmentation_dataset\\images\\000000892.png',
#  '../segmentation_dataset\\images\\000000893.png',
#  '../segmentation_dataset\\images\\000000894.png',
#  '../segmentation_dataset\\images\\000000895.png',
#  '../segmentation_dataset\\images\\000000896.png',
#  '../segmentation_dataset\\images\\000000897.png',
#  '../segmentation_dataset\\images\\000000898.png',
#  '../segmentation_dataset\\images\\000000899.png',
#  '../segmentation_dataset\\images\\000000900.png',
#  '../segmentation_dataset\\images\\000000901.png',
#  '../segmentation_dataset\\images\\000000902.png',
#  '../segmentation_dataset\\images\\000000903.png',
#  '../segmentation_dataset\\images\\000000904.png',
#  '../segmentation_dataset\\images\\000000905.png',
#  '../segmentation_dataset\\images\\000000906.png',
#  '../segmentation_dataset\\images\\000000907.png',
#  '../segmentation_dataset\\images\\000000908.png',
#  '../segmentation_dataset\\images\\000000909.png',
#  '../segmentation_dataset\\images\\000000910.png',
#  '../segmentation_dataset\\images\\000000911.png',
#  '../segmentation_dataset\\images\\000000912.png',
#  '../segmentation_dataset\\images\\000000913.png',
#  '../segmentation_dataset\\images\\000000914.png',
#  '../segmentation_dataset\\images\\000000915.png',
#  '../segmentation_dataset\\images\\000000916.png',
#  '../segmentation_dataset\\images\\000000917.png',
#  '../segmentation_dataset\\images\\000000918.png',
#  '../segmentation_dataset\\images\\000000919.png',
#  '../segmentation_dataset\\images\\000000920.png',
#  '../segmentation_dataset\\images\\000000921.png',
#  '../segmentation_dataset\\images\\000000922.png',
#  '../segmentation_dataset\\images\\000000923.png',
#  '../segmentation_dataset\\images\\000000924.png',
#  '../segmentation_dataset\\images\\000000925.png',
#  '../segmentation_dataset\\images\\000000926.png',
#  '../segmentation_dataset\\images\\000000927.png',
#  '../segmentation_dataset\\images\\000000928.png',
#  '../segmentation_dataset\\images\\000000929.png',
#  '../segmentation_dataset\\images\\000000930.png',
#  '../segmentation_dataset\\images\\000000931.png',
#  '../segmentation_dataset\\images\\000000932.png',
#  '../segmentation_dataset\\images\\000000933.png',
#  '../segmentation_dataset\\images\\000000934.png',
#  '../segmentation_dataset\\images\\000000935.png',
#  '../segmentation_dataset\\images\\000000936.png',
#  '../segmentation_dataset\\images\\000000937.png',
#  '../segmentation_dataset\\images\\000000938.png',
#  '../segmentation_dataset\\images\\000000939.png',
#  '../segmentation_dataset\\images\\000000940.png',
#  '../segmentation_dataset\\images\\000000941.png',
#  '../segmentation_dataset\\images\\000000942.png',
#  '../segmentation_dataset\\images\\000000943.png',
#  '../segmentation_dataset\\images\\000000944.png',
#  '../segmentation_dataset\\images\\000000945.png',
#  '../segmentation_dataset\\images\\000000946.png',
#  '../segmentation_dataset\\images\\000000947.png',
#  '../segmentation_dataset\\images\\000000948.png',
#  '../segmentation_dataset\\images\\000000949.png',
#  '../segmentation_dataset\\images\\000000950.png',
#  '../segmentation_dataset\\images\\000000951.png',
#  '../segmentation_dataset\\images\\000000952.png',
#  '../segmentation_dataset\\images\\000000953.png',
#  '../segmentation_dataset\\images\\000000954.png',
#  '../segmentation_dataset\\images\\000000955.png',
#  '../segmentation_dataset\\images\\000000956.png',
#  '../segmentation_dataset\\images\\000000957.png',
#  '../segmentation_dataset\\images\\000000958.png',
#  '../segmentation_dataset\\images\\000000959.png',
#  '../segmentation_dataset\\images\\000000960.png',
#  '../segmentation_dataset\\images\\000000961.png',
#  '../segmentation_dataset\\images\\000000962.png',
#  '../segmentation_dataset\\images\\000000963.png',
#  '../segmentation_dataset\\images\\000000964.png',
#  '../segmentation_dataset\\images\\000000965.png',
#  '../segmentation_dataset\\images\\000000966.png',
#  '../segmentation_dataset\\images\\000000967.png',
#  '../segmentation_dataset\\images\\000000968.png',
#  '../segmentation_dataset\\images\\000000969.png',
#  '../segmentation_dataset\\images\\000000970.png',
#  '../segmentation_dataset\\images\\000000971.png',
#  '../segmentation_dataset\\images\\000000972.png',
#  '../segmentation_dataset\\images\\000000973.png',
#  '../segmentation_dataset\\images\\000000974.png',
#  '../segmentation_dataset\\images\\000000975.png',
#  '../segmentation_dataset\\images\\000000976.png',
#  '../segmentation_dataset\\images\\000000977.png',
#  '../segmentation_dataset\\images\\000000978.png',
#  '../segmentation_dataset\\images\\000000979.png',
#  '../segmentation_dataset\\images\\000000980.png',
#  '../segmentation_dataset\\images\\000000981.png',
#  '../segmentation_dataset\\images\\000000982.png',
#  '../segmentation_dataset\\images\\000000983.png',
#  '../segmentation_dataset\\images\\000000984.png',
#  '../segmentation_dataset\\images\\000000985.png',
#  '../segmentation_dataset\\images\\000000986.png',
#  '../segmentation_dataset\\images\\000000987.png',
#  '../segmentation_dataset\\images\\000000988.png',
#  '../segmentation_dataset\\images\\000000989.png',
#  '../segmentation_dataset\\images\\000000990.png',
#  '../segmentation_dataset\\images\\000000991.png',
#  '../segmentation_dataset\\images\\000000992.png',
#  '../segmentation_dataset\\images\\000000993.png',
#  '../segmentation_dataset\\images\\000000994.png',
#  '../segmentation_dataset\\images\\000000995.png',
#  '../segmentation_dataset\\images\\000000996.png',
#  '../segmentation_dataset\\images\\000000997.png',
#  '../segmentation_dataset\\images\\000000998.png',
#  '../segmentation_dataset\\images\\000000999.png',
#  ...]

# %% [markdown]
# ## Labels & Output

# %% [markdown]
# To fit an Encoder-Decoder Neural Network; you will need to preprocess your labels. Currently, **your labels are RGB images of dimension 160x80x3.**
#
# As you can see here, we have multiple options, and I will detail all 3 of them.<p>
# ![Texte alternatif…](http://ronny.rest/media/tutorials/segmentation/ZZZ_IMAGES_DIR/label_formats.jpeg)
#
#
# *   **A- Class Labels**
# Each Pixel is a number representing a class.<p>
# In this case, the output is simply a matrix of 1 channel with these numbers.
# *   **B- RGB Mappings**
# This is what we currently have, the labels are in RGB format.<p>
# As we are only working with 2 classes, and they all are colored either red or blue, it's quite easy to work with.
# If you ever get more classes, let's say 7, some pixels will not be 0 or 255, they will have some intensity value and it will get more complicated.
# Preprocessing is therefore necessary.
# *   **C- One Hot Vectors**
# Similar to format A, but one-hot encoded.

# %% [markdown]
# **Your Choice**
#
# For this project, you have the choice to detect only the driveable area or the driveable area + the adjacent lanes. <p>
#
# You will therefore
# *   Remove every blue pixel and face a 1-channel problem (driveable area detection)
# *   Keep the blue pixel, use 3 channels.<p>**One easy solution would be to convert every black pixel into a green one.**
# Then, the network would have to label a pixel as either green (background), red (driveable), or blue (adjacent).

# %%
## YOUR CODE HERE
## Preprocess the labels to either remove the blue channel or convert the black pixels into green pixels.
## You can also convert the labels into a matrix (Option A previously showed)

label = np.unpackbits(labels[0], count=2764800).reshape((720, 1280, 3)).astype(np.float32)

# %% [markdown]
# For the data augmentation we wil convert black pixel into green pixels for the background

# %% [markdown]
# **Data Augmentation**
#
# 3,000 images can be enough, but in Deep Learning, **more is better**.
# If you want a strong model performance, feel free to augment your dataset any way you want.

# %%
## YOUR CODE HERE
## Augment your images if you think it's necessary
## Below is an example of flipping the image to double the size of the dataset
# Out:
# 6000
# 6000

# %% [markdown]
# #### Use opencv2 to augment the data

# %%
import cv2 
image = images[0]
# label = np.unpackbits(labels[0], count=2764800).reshape((720, 1280, 3))
label = processed_labels[0]

_, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 10))
ax1.imshow(image)
ax2.imshow(label.astype(float));

# %%
# flip across vertical axis
_, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 10))
ax1.imshow(cv2.flip(image, 1))
ax2.imshow(cv2.flip(label, 1).astype(float))

# %%
def random_rotate(image, label, angle=45):
    ''' Applys random rotation to image and label. Leaves part of the the 
        image cropped out which is desireable for this scenario since
        it further diversifies the data
        '''
    center = (image.shape[1] // 2, image.shape[0] // 2)
    angle = np.random.uniform(-angle, angle)
    rot = cv2.getRotationMatrix2D(center, angle, scale=1)
    rotated_image = cv2.warpAffine(image, rot, image.shape[1::-1], flags=cv2.INTER_LINEAR)
    rotated_label = cv2.warpAffine(label, rot, image.shape[1::-1], flags=cv2.INTER_LINEAR)
    return rotated_image, rotated_label

# %%
rotated_image, rotated_label = random_rotate(image, label, angle=45)

_, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 10))
ax1.imshow(rotated_image)
ax2.imshow(rotated_label.astype(float));

# %%
import elasticdeform

[deformed_image, deformed_label] = elasticdeform.deform_random_grid([image, label.astype(np.float32)], axis=(0, 1))
_, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 10))
ax1.imshow(deformed_image)
ax2.imshow(deformed_label) # .astype(float));
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# Now apply augmentations to the data
augmented_images = []
augmented_labels = []
for image, label in zip(images, processed_labels):
    # perform random horizotnal flip
    if np.random.uniform(0, 1) >= 0.5:
        image = cv2.flip(image, 1)
        label = cv2.flip(label, 1)

    # perform elastic deformation
    [deformed_image, deformed_label] = elasticdeform.deform_random_grid([image, label.astype(np.float32)], 
                                                                        axis=(0, 1))

    # perform random rotation and "crop" (it's a feature!)
    rotated_image, rotated_label = random_rotate(deformed_image, deformed_label, angle=25)

    augmented_images.append(rotated_image.astype(np.uint8))
    augmented_labels.append(rotated_label.astype(np.float32))

    gc.collect()

# %%
del images

# %%
# save augmented data
with open("../segmentation_dataset/augmented_images_3000_original.p", 'wb') as f_obj:
        pickle.dump(augmented_images, f_obj)

reduced_augmented_labels = []
for i, label in enumerate(augmented_labels):
        reduced_augmented_labels.append(np.packbits(label.astype(np.bool_)))
        gc.collect()

with open("../segmentation_dataset/augmented_labels_3000_original_1_REDUCED.p", 'wb') as f_obj:
        pickle.dump(reduced_augmented_labels, f_obj)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\itber\Documents\learning\think_autonomous_main\segmentation_course\Driveable_Area_Starter.ipynb Cell 36 in <cell line: 6>()
#       <a href='vscode-notebook-cell:/c%3A/Users/itber/Documents/learning/think_autonomous_main/segmentation_course/Driveable_Area_Starter.ipynb#Y151sZmlsZQ%3D%3D?line=5'>6</a> for i, label in enumerate(augmented_labels):
#       <a href='vscode-notebook-cell:/c%3A/Users/itber/Documents/learning/think_autonomous_main/segmentation_course/Driveable_Area_Starter.ipynb#Y151sZmlsZQ%3D%3D?line=6'>7</a>         reduced_augmented_labels.append(np.packbits(label.astype(np.bool_)))
# ----> <a href='vscode-notebook-cell:/c%3A/Users/itber/Documents/learning/think_autonomous_main/segmentation_course/Driveable_Area_Starter.ipynb#Y151sZmlsZQ%3D%3D?line=7'>8</a>         gc.collect()
#      <a href='vscode-notebook-cell:/c%3A/Users/itber/Documents/learning/think_autonomous_main/segmentation_course/Driveable_Area_Starter.ipynb#Y151sZmlsZQ%3D%3D?line=9'>10</a> with open("../segmentation_dataset/augmented_labels_3000_original_1_REDUCED.p", 'wb') as f_obj:
#      <a href='vscode-notebook-cell:/c%3A/Users/itber/Documents/learning/think_autonomous_main/segmentation_course/Driveable_Area_Starter.ipynb#Y151sZmlsZQ%3D%3D?line=10'>11</a>         pickle.dump(reduced_augmented_labels, f_obj)
#
# KeyboardInterrupt:

# %% [markdown]
# new method, just use images, the pickle files don't save us any memory expect for labels since they can be compressed
#
# https://stackoverflow.com/questions/50268092/save-1-bit-deep-binary-image-in-python

# %% [markdown]
# **Train Test Split**<p>
# As for every neural network, you will need **training** and **testing** data.

# %% [markdown]
# For the total dataset we will combine the 50% of the unagumented data and use the remaining 50% and augmented data for training. Possible validate on 35% of the original dataset and test on the remaining 15% of the data.
#
# Need to find out how to load data from disk durng training

# %%
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

# %%
## YOUR CODE HERE
## SPLIT THE DATASET

# %% [markdown]
# # <a name="Model"></a>2. Create A Deep Learning Model

# %% [markdown]
# ## Model Definition
#
# Here, we will define a Fully Convolutional Neural Network.<p>
# It actually means a **neural networks that doesn't have any Dense layer** (or Fully Connected), but **only Convolutions**.
#
# ![Texte alternatif…](https://mi.eng.cam.ac.uk/projects/segnet/images/segnet.png)
#
# We will use **Keras**.<p>
# [Here is a way to use Keras for Deep Learning](https://keras.io/getting-started/functional-api-guide/).
#
# **What should we implement?**
#
#
# 1.   Create an **encoder** that learns the features
# 2.   Create a **decoder** that upsamples to the original image size
# 3.   Implement advanced techniques such as **1x1 convolutions**, or **skip connections** to make the neural network better.
#
# To avoid overfitting, we can use **Dropout**.
# To make the network better, we can use **Batch Normalization** after the input. In semantic segmentation, Batch Normalization have proven amazing results.
#
# Feel free to explore as you build your model.
# You can also build a model from existing models.
#
# *   [UNet](https://arxiv.org/pdf/1505.04597.pdf)
# *   [SegNet](https://arxiv.org/pdf/1511.00561.pdf)
# *   [FCN](https://arxiv.org/pdf/1411.4038.pdf)
# *   [DeepLab](https://arxiv.org/pdf/1606.00915.pdf)

# %% [markdown]
# **Imports**

# %%
from tensorflow.python import keras
from tensorflow.python.keras.models import Sequential, Model
from tensorflow.python.keras.layers import Activation, Dropout, Conv2D, MaxPooling2D, Reshape, Input, add
from tensorflow.python.keras.layers import UpSampling2D, Conv2DTranspose
from tensorflow.python.keras.layers.normalization import BatchNormalization
from tensorflow.python.keras.preprocessing.image import ImageDataGenerator
from tensorflow.python.keras import regularizers

# %% [markdown]
# **Build your Model**

# %%
def simple_encoder_decoder():
    """
    Try a simple Encoder-Decoder architecture.
    Use Convolutions, Transposed Convolutions.
    Use Pooling, Unpooling or UpSampling.
    GOAL: Match the output to the input. Experiment.
    """
    ## YOUR CODE HERE
    input_x = Input(shape=(80,160,3))
    x = BatchNormalization(input_shape=(80,160,3))(input_x)
    x = Conv2D(32, (3, 3), padding='valid', strides=(1,1), activation = 'relu')(x)
    x1 = BatchNormalization()(x)
    x = MaxPooling2D(pool_size=(2,2))(x1)
    x = UpSampling2D(interpolation='bilinear')(x)
    x = add([x1, x])
    x = Conv2DTranspose(32,(3,3),strides=(1,1), padding='valid', activation='relu')(x)
    x = Conv2D(3, (1,1), strides=(1,1), padding='valid',activation='softmax')(x)
    return Model(input_x,x)

model = simple_encoder_decoder() 
model.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_6 (InputLayer)            [(None, 80, 160, 3)] 0
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 80, 160, 3)   12          input_6[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 78, 158, 32)  896         batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 78, 158, 32)  128         conv2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 39, 79, 32)   0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 78, 158, 32)  0           max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 78, 158, 32)  0           batch_normalization_9[0][0]
#                                                                  up_sampling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 80, 160, 32)  9248        add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 80, 160, 3)   99          conv2d_transpose_2[0][0]
# ==================================================================================================
# Total params: 10,383
# Trainable params: 10,313
# Non-trainable params: 70
# __________________________________________________________________________________________________

# %% [markdown]
# ## MODEL TRAINING
#
# Use any technique you know to improve model training or generalization.
#
#
# *   If you want to detect **1 class (driveable area)**, you can use **binary cross-entropy or mean squared error** as a metric.
# *  If you want to detect **2 or more classes** (driveable area + adjacent), you can use **categorical cross-entropy** as a metric. <p>
#
# You are free to use any optimizer you want.

# %% [markdown]
# **Hyperparameters**

# %%
batch_size = 
epochs = 
pool_size = 
learning_rate = 
steps_per_epoch = 
input_shape = X_train.shape[1:]

# %% [markdown]
# **Training**

# %%
# Using a generator to help the model use less data
# Channel shifts help with shadows slightly
datagen = ImageDataGenerator(channel_shift_range=0.2)
datagen.fit(X_train)

# Compiling and training the model
model.compile()
history = model.fit(datagen.flow(X_train, y_train, batch_size=batch_size), steps_per_epoch=steps_per_epoch, 
          epochs=epochs, verbose=1, learning_rate=learning_rate, validation_data=(X_val, y_val))
# Freeze layers since training is done

# Save model architecture and weights
model.save('model.h5')

# %% [markdown]
# **Plot Training Results**

# %%
print(history.history.keys())
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.show()

# %% [markdown]
# ## Test the model and Build a general pipeline

# %%
def rgb_channel(img, thresholding=False, thresh=230):
    """Threshold the re-drawn images
    Returns R, G, B channels"""
    image = np.copy(img)
    if thresholding:
        ret, image = cv2.threshold(image, thresh, 255, cv2.THRESH_BINARY)
    R = image[:,:,0]
    G = image[:,:,1]
    B = image[:,:,2]
    return R,G,B

# %% [markdown]
# **Build the Run Function**
# The run function must:
# * Take an image as input
# * Resize the input to match the model size
# * Call model.predict()
# * Extract R,G,B channels from prediction
# * Rescale to the original image size
# * Draw on the input image
# * Return the result

# %%
def run(input_image):
    ## YOUR CODE HERE
    pass

# %% [markdown]
# **Test from the dataset**

# %%
index = random.randint(0,len(images))

img_test = run(images[index])

f, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(20,10))
ax1.imshow(images[index].squeeze())
ax1.set_title('Image', fontsize=30)
ax2.imshow(labels[index].squeeze())
ax2.set_title('Label', fontsize=30)
ax3.imshow(img_test)
ax3.set_title("Drawn Prediction", fontsize=30)
# Out:
# Text(0.5, 1.0, 'Drawn Prediction')

# %% [markdown]
# **Test on a never seen image**

# %%
predict_image = mpimg.imread("yourpathhere")
plt.imshow(run(predict_image))
plt.show()

# %% [markdown]
# # <a name="Video"></a>3. Run on a Video
#
# Here is the best part. FCN models generally are fast. They can run on CPU at 5 FPS and on GPU at a very high frame rate.<p>
# Test your code on a video and see how it worked.

# %%
from moviepy.editor import VideoFileClip
video_file = "/content/drive/My Drive/video_path_here"
clip = VideoFileClip(video_file).subclip(0,30).set_fps(15)
white_clip = clip.fl_image(run)
# %time white_clip.write_videofile("output.mp4",audio=False)

# %% [markdown]
# **Costa Rica Challenge**<p>
# Try your algorithm on Costa Rica roads!
# Use the files **costa_rica_challenge** and **costa_rica_challenge_2** provided.<P>
# /!\ video was taken from an iPhone X at 60 FPS and 4K resolution...

# %%
## VIDEO IS TAKEN AT 60 FPS ON 4K RESOLUTION; NO IMAGE DISTORTION CORRECTION IS DONE
## THE PROGRAM HERE RUNS ON CPU AT 2 FPS; RUN ON YOUR OWN MACHINE FOR BETTER PERFORMANCE
